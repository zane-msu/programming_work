# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# load in datasets separately
cbb = pd.read_csv("cbb.csv")
cbb2020 = pd.read_csv("cbb20.csv")


# perform linear regression to get a rough idea which stats are most associated with wins
Y = cbb[['W']] # dependent variable is wins
# team stats are the independent variables
X = cbb[['ADJOE','ADJDE','BARTHAG','EFG_O','EFG_D','TOR','TORD','ORB','DRB','FTR','FTRD','2P_O','2P_D','3P_O','3P_D','ADJ_T','WAB']]
x_vars = list(X.columns.values) # make a list of independend variable names for dataframe

# perform linear regression
cbb_reg = LinearRegression()
cbb_reg.fit(X, Y)

# create dataframe to show coefficients and variables together
coefficients = pd.concat([pd.DataFrame({'Variable':X.columns}),pd.DataFrame(np.transpose(cbb_reg.coef_))], axis = 1)
coef_sum = coefficients.rename(columns={0:'Coefficient'}) # make new df after renaming coefficient column
coef_sum
# Out:
#    Variable  Coefficient
# 0     ADJOE    -0.184692
# 1     ADJDE     0.349388
# 2   BARTHAG    -2.871174
# 3     EFG_O     1.107144
# 4     EFG_D    -0.995670
# 5       TOR    -0.488813
# 6      TORD     0.760188
# 7       ORB     0.212232
# 8       DRB    -0.422526
# 9       FTR     0.023990
# 10     FTRD    -0.105644
# 11     2P_O    -0.364252
# 12     2P_D     0.177252
# 13     3P_O    -0.284535
# 14     3P_D     0.059212
# 15    ADJ_T     0.081056
# 16      WAB     0.818737

# %%
# function for predicting team wins in each conference

def total_win_predict(past_data, pred_data):
    confs = pred_data.CONF.unique() # conference names to loop through
    accuracy_scores = [] # empty list to be filled with accuracy scores for each conference
    for i in confs:
        # mask stats by conference i
        conf_past = past_data.loc[past_data['CONF'] == i] 
        conf_pred = pred_data.loc[pred_data['CONF'] == i]
        # create list of team names and actual wins for dataframes
        teams = list(conf_pred.TEAM)
        actual_wins = list(conf_pred.W)
        
        # split train and test data (past is train, current is test)
        # features are the stats, target is the number of wins
        features_train = conf_past[['ADJOE','ADJDE','BARTHAG','EFG_O','EFG_D','TOR','TORD','ORB','DRB','FTR','FTRD','2P_O','2P_D','3P_O','3P_D','ADJ_T','WAB']]
        target_train = conf_past[['W']]
        features_test = conf_pred[['ADJOE','ADJDE','BARTHAG','EFG_O','EFG_D','TOR','TORD','ORB','DRB','FTR','FTRD','2P_O','2P_D','3P_O','3P_D','ADJ_T','WAB']]
        target_test = conf_pred[['W']]
        
        # perform logistic regression
        log_reg = LogisticRegression().fit(features_train, target_train)
        # make win prediction based on trained logistic regression model
        wins_pred = log_reg.predict(features_test)
        # calculate accuracy (how close predicted wins are to actual for the conference (how many were predicted correctly))
        accuracy = accuracy_score(target_test, wins_pred)
        # add accuracy score to empty accuracy list
        accuracy_scores.append(accuracy)
        
        # create dataframe comparing predicted wins and actual wins 
        data = {'TEAM': teams, 'Predicted Wins': wins_pred, 'Actual Wins': actual_wins}
        conf_summary = pd.DataFrame.from_dict(data)
        
        print(i)
        print(conf_summary)
        print("Accuracy: \n", accuracy)
        
    # create dataframe with accuracy score for each conference
    accuracy_data = {'CONF': confs, 'Prediction Accuracy': accuracy_scores}
    accuracy_summary = pd.DataFrame.from_dict(accuracy_data)
    print(accuracy_summary)

# %%
total_win_predict(cbb, cbb2020)
# Out:
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# B12
#             TEAM  Predicted Wins  Actual Wins
# 0         Kansas              31           28
# 1         Baylor              24           26
# 2  West Virginia              27           21
# 3     Texas Tech              23           18
# 4       Oklahoma              20           19
# 5   Oklahoma St.              17           18
# 6          Texas              24           19
# 7            TCU              24           16
# 8       Iowa St.              24           12
# 9     Kansas St.              11           11
# Accuracy:
#  0.1
# WCC
#                TEAM  Predicted Wins  Actual Wins
# 0           Gonzaga              22           31
# 1               BYU              17           24
# 2      Saint Mary's              17           25
# 3     San Francisco              22           22
# 4           Pacific              20           23
# 5        Pepperdine              17           16
# 6       Santa Clara              19           19
# 7  Loyola Marymount              22           11
# 8         San Diego              22            9
# 9          Portland              16            9
# Accuracy:
#  0.2
# A10
#                  TEAM  Predicted Wins  Actual Wins
# 0              Dayton              25           29
# 1            Richmond              24           24
# 2         Saint Louis              25           23
# 3                 VCU              18           18
# 4            Davidson              13           16
# 5        Rhode Island              19           21
# 6            Duquesne              22           21
# 7     St. Bonaventure              23           19
# 8       Massachusetts              18           14
# 9        George Mason              18           17
# 10           La Salle              22           15
# 11  George Washington              14           12
# 12            Fordham              10            9
# 13     Saint Joseph's               9            6
# Accuracy:
#  0.14285714285714285
# B10
#             TEAM  Predicted Wins  Actual Wins
# 0   Michigan St.              26           22
# 1       Ohio St.              27           21
# 2       Michigan              26           19
# 3       Penn St.              24           21
# 4      Wisconsin              15           21
# 5         Purdue              15           16
# 6       Maryland              19           24
# 7      Minnesota              26           15
# 8       Illinois              19           21
# 9        Rutgers              19           20
# 10          Iowa              23           20
# 11       Indiana              14           20
# 12  Northwestern              15            8
# 13      Nebraska              19            7
# Accuracy:
#  0.0
# ACC
#                   TEAM  Predicted Wins  Actual Wins
# 0                 Duke              23           25
# 1           Louisville              22           24
# 2          Florida St.              26           26
# 3             Virginia              21           23
# 4             Syracuse              14           18
# 5   North Carolina St.              24           20
# 6         Georgia Tech              14           17
# 7           Notre Dame              14           20
# 8              Clemson              14           16
# 9       North Carolina              14           14
# 10         Wake Forest              13           13
# 11            Miami FL              14           15
# 12       Virginia Tech              24           16
# 13          Pittsburgh              18           16
# 14      Boston College              14           13
# Accuracy:
#  0.2
# BE
#          TEAM  Predicted Wins  Actual Wins
# 0   Creighton              20           24
# 1   Villanova              21           24
# 2  Seton Hall              25           21
# 3      Butler              26           22
# 4  Providence              24           19
# 5   Marquette              15           18
# 6      Xavier              24           19
# 7  St. John's              16           17
# 8  Georgetown              19           15
# 9      DePaul              16           16
# Accuracy:
#  0.1
# MWC
#              TEAM  Predicted Wins  Actual Wins
# 0   San Diego St.              23           30
# 1        Utah St.              23           26
# 2          Nevada              23           19
# 3            UNLV              22           17
# 4       Boise St.              23           20
# 5    Colorado St.              17           20
# 6      New Mexico              17           19
# 7      Fresno St.              15           11
# 8       Air Force              12           12
# 9         Wyoming              13            9
# 10   San Jose St.              11            7
# Accuracy:
#  0.09090909090909091
# Amer
#              TEAM  Predicted Wins  Actual Wins
# 0         Houston              26           23
# 1     Wichita St.              27           23
# 2      Cincinnati              23           20
# 3     Connecticut              15           19
# 4         Memphis              18           21
# 5           Tulsa              23           21
# 6             SMU              15           19
# 7             UCF              23           16
# 8   South Florida              23           14
# 9          Temple              19           14
# 10         Tulane              23           12
# 11  East Carolina              10           11
# Accuracy:
#  0.0
# P12
#               TEAM  Predicted Wins  Actual Wins
# 0          Arizona              23           21
# 1           Oregon              25           24
# 2         Colorado              21           21
# 3         Stanford              23           20
# 4       Washington              19           15
# 5              USC              21           22
# 6      Arizona St.              23           20
# 7             UCLA              18           19
# 8       Oregon St.              20           18
# 9             Utah              26           16
# 10  Washington St.              17           16
# 11      California              18           14
# Accuracy:
#  0.08333333333333333
# SEC
#                TEAM  Predicted Wins  Actual Wins
# 0          Kentucky              18           25
# 1           Florida              21           19
# 2            Auburn              28           25
# 3               LSU              21           21
# 4   Mississippi St.              21           20
# 5          Arkansas              19           20
# 6           Alabama              19           16
# 7    South Carolina              26           18
# 8         Tennessee              20           17
# 9           Georgia              25           16
# 10         Missouri              26           15
# 11      Mississippi              19           15
# 12        Texas A&M              18           16
# 13       Vanderbilt              19           11
# Accuracy:
#  0.07142857142857142
# MVC
#                 TEAM  Predicted Wins  Actual Wins
# 0      Northern Iowa              17           25
# 1     Loyola Chicago              23           21
# 2            Bradley              17           23
# 3        Indiana St.              22           18
# 4       Missouri St.              17           16
# 5              Drake              20           20
# 6  Southern Illinois              15           16
# 7         Valparaiso              17           19
# 8       Illinois St.              17           10
# 9         Evansville              16            9
# Accuracy:
#  0.1
# CUSA
#                 TEAM  Predicted Wins  Actual Wins
# 0        North Texas              31           20
# 1     Louisiana Tech              25           22
# 2   Western Kentucky              20           20
# 3                FIU              25           19
# 4           Marshall              26           17
# 5          Charlotte              15           16
# 6       Old Dominion              17           13
# 7                UAB              20           19
# 8   Florida Atlantic              20           17
# 9               Rice              20           15
# 10              UTEP              20           17
# 11              UTSA              20           13
# 12     Southern Miss              11            9
# 13  Middle Tennessee               9            8
# Accuracy:
#  0.07142857142857142
# Ivy
#         TEAM  Predicted Wins  Actual Wins
# 0       Yale              22           23
# 1    Harvard              18           21
# 2       Penn              12           16
# 3  Princeton              19           14
# 4  Dartmouth              16           12
# 5      Brown              18           15
# 6    Cornell              13            7
# 7   Columbia               8            6
# Accuracy:
#  0.0
# SC
#                  TEAM  Predicted Wins  Actual Wins
# 0  East Tennessee St.              27           30
# 1              Furman              23           25
# 2      UNC Greensboro              29           23
# 3         Chattanooga              23           20
# 4             Wofford              23           19
# 5    Western Carolina              23           19
# 6              Mercer              16           17
# 7                 VMI              16            9
# 8             Samford               9           10
# 9         The Citadel              11            6
# Accuracy:
#  0.0
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# ASun
#                  TEAM  Predicted Wins  Actual Wins
# 0             Liberty              17           30
# 1       North Florida              19           21
# 2        Jacksonville              10           14
# 3            Lipscomb              14           16
# 4             Stetson              17           16
# 5                NJIT              10            9
# 6       North Alabama              10           13
# 7  Florida Gulf Coast              14           10
# 8        Kennesaw St.               5            1
# Accuracy:
#  0.0
# SB
#                    TEAM  Predicted Wins  Actual Wins
# 0             Texas St.              17           21
# 1           Georgia St.              20           19
# 2          UT Arlington              16           14
# 3           Little Rock              22           21
# 4      Georgia Southern              21           20
# 5         South Alabama              22           20
# 6      Coastal Carolina              20           16
# 7       Appalachian St.              21           18
# 8   Louisiana Lafayette              21           14
# 9          Arkansas St.              13           16
# 10     Louisiana Monroe              10            9
# 11                 Troy              11            9
# Accuracy:
#  0.0
# MAC
#                  TEAM  Predicted Wins  Actual Wins
# 0               Akron              23           24
# 1            Ball St.              20           18
# 2            Kent St.              17           20
# 3             Buffalo              16           20
# 4                Ohio              17           17
# 5       Bowling Green              22           21
# 6              Toledo              21           17
# 7   Northern Illinois              21           18
# 8    Eastern Michigan              15           16
# 9    Central Michigan              14           14
# 10           Miami OH              14           13
# 11   Western Michigan              21           13
# Accuracy:
#  0.16666666666666666
# WAC
#                    TEAM  Predicted Wins  Actual Wins
# 0        New Mexico St.              30           25
# 1           Cal Baptist               9           21
# 2               Seattle              20           14
# 3                  UMKC              10           16
# 4  UT Rio Grande Valley              20           14
# 5   Cal St. Bakersfield              11           12
# 6           Utah Valley              17           11
# 7          Grand Canyon              20           13
# 8           Chicago St.               3            4
# Accuracy:
#  0.0
# AE
#             TEAM  Predicted Wins  Actual Wins
# 0        Vermont              21           26
# 1    Stony Brook              24           20
# 2       Hartford              15           18
# 3  New Hampshire              21           15
# 4           UMBC              21           16
# 5   UMass Lowell              12           13
# 6         Albany              12           14
# 7          Maine               6            9
# 8     Binghamton              10           10
# Accuracy:
#  0.1111111111111111
# BSky
#                   TEAM  Predicted Wins  Actual Wins
# 0    Northern Colorado              26           22
# 1              Montana              12           18
# 2   Eastern Washington              22           23
# 3         Portland St.              20           18
# 4        Southern Utah              22           17
# 5       Sacramento St.              15           16
# 6          Montana St.              14           16
# 7     Northern Arizona              15           16
# 8            Weber St.               7           12
# 9            Idaho St.              11            8
# 10               Idaho              14            8
# Accuracy:
#  0.0
# OVC
#                       TEAM  Predicted Wins  Actual Wins
# 0                  Belmont              24           26
# 1               Murray St.              26           23
# 2              Austin Peay              22           21
# 3         Eastern Illinois              10           17
# 4            Tennessee St.              23           18
# 5         Eastern Kentucky              13           16
# 6         Jacksonville St.              10           13
# 7             Morehead St.              10           13
# 8         SIU Edwardsville              10            8
# 9           Tennessee Tech              10            9
# 10        Tennessee Martin              10            9
# 11  Southeast Missouri St.              10            7
# Accuracy:
#  0.0
# Slnd
#                       TEAM  Predicted Wins  Actual Wins
# 0        Stephen F. Austin              16           28
# 1        Abilene Christian              19           20
# 2             Nicholls St.              21           21
# 3          Sam Houston St.              19           18
# 4                    Lamar              12           17
# 5         Northwestern St.              10           15
# 6              McNeese St.              13           15
# 7         Central Arkansas              12           10
# 8   Texas A&M Corpus Chris              17           14
# 9              New Orleans              11            9
# 10  Southeastern Louisiana              19            8
# 11         Houston Baptist               6            4
# 12          Incarnate Word              11            9
# Accuracy:
#  0.07692307692307693
# CAA
#                     TEAM  Predicted Wins  Actual Wins
# 0                Hofstra              27           26
# 1           Northeastern              18           17
# 2                 Towson              18           18
# 3               Delaware              18           22
# 4  College of Charleston              18           17
# 5         William & Mary              18           21
# 6                 Drexel              18           14
# 7                   Elon              11           12
# 8          James Madison              10            9
# 9         UNC Wilmington              13           10
# Accuracy:
#  0.1
# BW
#                  TEAM  Predicted Wins  Actual Wins
# 0           UC Irvine              31           21
# 1    UC Santa Barbara              22           21
# 2              Hawaii              18           17
# 3        UC Riverside              12           17
# 4  Cal St. Northridge              13           15
# 5            UC Davis              22           14
# 6   Cal St. Fullerton              16           11
# 7      Long Beach St.               9           11
# 8            Cal Poly               9            7
# Accuracy:
#  0.0
# Horz
#                 TEAM  Predicted Wins  Actual Wins
# 0         Wright St.              25           25
# 1  Northern Kentucky              12           23
# 2   Illinois Chicago              20           18
# 3          Green Bay              13           17
# 4            Oakland              12           14
# 5     Youngstown St.              12           18
# 6          Milwaukee              13           12
# 7            Detroit              12            8
# 8      Cleveland St.              12           11
# 9              IUPUI              12            7
# Accuracy:
#  0.1
# Sum
#                TEAM  Predicted Wins  Actual Wins
# 0  North Dakota St.              13           25
# 1  South Dakota St.              24           22
# 2      Oral Roberts              18           17
# 3      South Dakota              13           20
# 4    Nebraska Omaha              11           16
# 5      North Dakota              13           15
# 6        Fort Wayne              18           14
# 7            Denver              13            7
# 8  Western Illinois               8            5
# Accuracy:
#  0.0
# Pat
#                 TEAM  Predicted Wins  Actual Wins
# 0            Colgate              24           25
# 1  Boston University              24           21
# 2           American              15           16
# 3          Lafayette              21           19
# 4           Bucknell              13           14
# 5               Navy              12           14
# 6               Army              21           15
# 7          Loyola MD              15           15
# 8             Lehigh              12           11
# 9         Holy Cross              12            3
# Accuracy:
#  0.1
# MAAC
#              TEAM  Predicted Wins  Actual Wins
# 0           Siena              21           20
# 1   Saint Peter's              18           18
# 2           Rider              16           18
# 3        Monmouth              13           18
# 4            Iona              13           12
# 5        Canisius              18           12
# 6      Quinnipiac              13           15
# 7       Manhattan              13           13
# 8       Fairfield              13           12
# 9         Niagara               7           12
# 10         Marist              13            7
# Accuracy:
#  0.18181818181818182
# BSth
#                    TEAM  Predicted Wins  Actual Wins
# 0              Winthrop              14           24
# 1               Radford              20           21
# 2          Gardner Webb              18           16
# 3              Campbell              10           15
# 4         UNC Asheville              20           15
# 5               Hampton              20           15
# 6   Charleston Southern              18           14
# 7              Longwood              15           14
# 8           USC Upstate               8           13
# 9          Presbyterian               7           10
# 10           High Point              15            9
# Accuracy:
#  0.0
# NEC
#                    TEAM  Predicted Wins  Actual Wins
# 0        St. Francis PA              18           22
# 1         Robert Morris              18           20
# 2          Sacred Heart              16           20
# 3             Merrimack              13           20
# 4                Bryant              16           15
# 5          LIU Brooklyn              18           15
# 6   Fairleigh Dickinson              18           11
# 7      Mount St. Mary's              15           11
# 8        St. Francis NY              13           13
# 9                Wagner              13            8
# 10  Central Connecticut              13            4
# Accuracy:
#  0.09090909090909091
# SWAC
#                      TEAM  Predicted Wins  Actual Wins
# 0                Southern              18           17
# 1        Prairie View A&M              22           19
# 2             Jackson St.              13           14
# 3          Texas Southern              13           16
# 4           Grambling St.              24           17
# 5              Alcorn St.              12           15
# 6             Alabama St.               7            8
# 7             Alabama A&M               4            8
# 8     Arkansas Pine Bluff               4            4
# 9  Mississippi Valley St.               6            4
# Accuracy:
#  0.1
# MEAC
#                       TEAM  Predicted Wins  Actual Wins
# 0              Norfolk St.               9           16
# 1       North Carolina A&T              13           17
# 2   North Carolina Central              13           18
# 3          Bethune Cookman              14           15
# 4              Florida A&M              13           12
# 5               Morgan St.              14           15
# 6               Coppin St.               8           11
# 7       South Carolina St.               8           11
# 8             Delaware St.               8            6
# 9                   Howard              10            4
# 10  Maryland Eastern Shore               6            5
# Accuracy:
#  0.0
#     CONF  Prediction Accuracy
# 0    B12             0.100000
# 1    WCC             0.200000
# 2    A10             0.142857
# 3    B10             0.000000
# 4    ACC             0.200000
# 5     BE             0.100000
# 6    MWC             0.090909
# 7   Amer             0.000000
# 8    P12             0.083333
# 9    SEC             0.071429
# 10   MVC             0.100000
# 11  CUSA             0.071429
# 12   Ivy             0.000000
# 13    SC             0.000000
# 14  ASun             0.000000
# 15    SB             0.000000
# 16   MAC             0.166667
# 17   WAC             0.000000
# 18    AE             0.111111
# 19  BSky             0.000000
# 20   OVC             0.000000
# 21  Slnd             0.076923
# 22   CAA             0.100000
# 23    BW             0.000000
# 24  Horz             0.100000
# 25   Sum             0.000000
# 26   Pat             0.100000
# 27  MAAC             0.181818
# 28  BSth             0.000000
# 29   NEC             0.090909
# 30  SWAC             0.100000
# 31  MEAC             0.000000
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
# function predicting wins for only the power 6 conferences

def total_win_predict_POWER(past_data, pred_data):
    power_confs = np.array(['B12','B10','ACC','BE','P12','SEC'], dtype = object) # power conference names only to loop through
    accuracy_scores = [] # empty list to be filled with accuracy scores for each power conference
    for i in power_confs:
        conf_past = past_data.loc[past_data['CONF'] == i]
        conf_pred = pred_data.loc[pred_data['CONF'] == i]
        # create list of team names and actual wins for dataframes
        teams = list(conf_pred.TEAM)
        actual_wins = list(conf_pred.W)
        
        # split train and test data (past is train, current is test)
        # features are the stats, target is the number of wins
        features_train = conf_past[['ADJOE','ADJDE','BARTHAG','EFG_O','EFG_D','TOR','TORD','ORB','DRB','FTR','FTRD','2P_O','2P_D','3P_O','3P_D','ADJ_T','WAB']]
        target_train = conf_past[['W']]
        features_test = conf_pred[['ADJOE','ADJDE','BARTHAG','EFG_O','EFG_D','TOR','TORD','ORB','DRB','FTR','FTRD','2P_O','2P_D','3P_O','3P_D','ADJ_T','WAB']]
        target_test = conf_pred[['W']]
        
        # perform logistic regression
        log_reg = LogisticRegression().fit(features_train, target_train)
        # make win prediction based on trained logistic regression model
        wins_pred = log_reg.predict(features_test)
        # calculate accuracy (how close predicted wins are to actual for the conference (how many were predicted correctly))
        accuracy = accuracy_score(target_test, wins_pred)
        # add accuracy score to empty accuracy list
        accuracy_scores.append(accuracy)
        
        # create dataframe comparing predicted wins and actual wins
        data = {'TEAM': teams, 'Predicted Wins': wins_pred, 'Actual Wins': actual_wins}
        conf_summary = pd.DataFrame.from_dict(data)
        
        print(i)
        print(conf_summary)
        print("Accuracy: \n", accuracy)
    
    # create dataframe with accuracy score for each power conference
    accuracy_data = {'CONF': power_confs, 'Prediction Accuracy': accuracy_scores}
    accuracy_summary = pd.DataFrame.from_dict(accuracy_data)
    print(accuracy_summary)

# %%
power_pred = total_win_predict_POWER(cbb,cbb2020)
# Out:
# B12
#             TEAM  Predicted Wins  Actual Wins
# 0         Kansas              31           28
# 1         Baylor              24           26
# 2  West Virginia              27           21
# 3     Texas Tech              23           18
# 4       Oklahoma              20           19
# 5   Oklahoma St.              17           18
# 6          Texas              24           19
# 7            TCU              24           16
# 8       Iowa St.              24           12
# 9     Kansas St.              11           11
# Accuracy:
#  0.1
# B10
#             TEAM  Predicted Wins  Actual Wins
# 0   Michigan St.              26           22
# 1       Ohio St.              27           21
# 2       Michigan              26           19
# 3       Penn St.              24           21
# 4      Wisconsin              15           21
# 5         Purdue              15           16
# 6       Maryland              19           24
# 7      Minnesota              26           15
# 8       Illinois              19           21
# 9        Rutgers              19           20
# 10          Iowa              23           20
# 11       Indiana              14           20
# 12  Northwestern              15            8
# 13      Nebraska              19            7
# Accuracy:
#  0.0
# ACC
#                   TEAM  Predicted Wins  Actual Wins
# 0                 Duke              23           25
# 1           Louisville              22           24
# 2          Florida St.              26           26
# 3             Virginia              21           23
# 4             Syracuse              14           18
# 5   North Carolina St.              24           20
# 6         Georgia Tech              14           17
# 7           Notre Dame              14           20
# 8              Clemson              14           16
# 9       North Carolina              14           14
# 10         Wake Forest              13           13
# 11            Miami FL              14           15
# 12       Virginia Tech              24           16
# 13          Pittsburgh              18           16
# 14      Boston College              14           13
# Accuracy:
#  0.2
# BE
#          TEAM  Predicted Wins  Actual Wins
# 0   Creighton              20           24
# 1   Villanova              21           24
# 2  Seton Hall              25           21
# 3      Butler              26           22
# 4  Providence              24           19
# 5   Marquette              15           18
# 6      Xavier              24           19
# 7  St. John's              16           17
# 8  Georgetown              19           15
# 9      DePaul              16           16
# Accuracy:
#  0.1
# P12
#               TEAM  Predicted Wins  Actual Wins
# 0          Arizona              23           21
# 1           Oregon              25           24
# 2         Colorado              21           21
# 3         Stanford              23           20
# 4       Washington              19           15
# 5              USC              21           22
# 6      Arizona St.              23           20
# 7             UCLA              18           19
# 8       Oregon St.              20           18
# 9             Utah              26           16
# 10  Washington St.              17           16
# 11      California              18           14
# Accuracy:
#  0.08333333333333333
# SEC
#                TEAM  Predicted Wins  Actual Wins
# 0          Kentucky              18           25
# 1           Florida              21           19
# 2            Auburn              28           25
# 3               LSU              21           21
# 4   Mississippi St.              21           20
# 5          Arkansas              19           20
# 6           Alabama              19           16
# 7    South Carolina              26           18
# 8         Tennessee              20           17
# 9           Georgia              25           16
# 10         Missouri              26           15
# 11      Mississippi              19           15
# 12        Texas A&M              18           16
# 13       Vanderbilt              19           11
# Accuracy:
#  0.07142857142857142
#   CONF  Prediction Accuracy
# 0  B12             0.100000
# 1  B10             0.000000
# 2  ACC             0.200000
# 3   BE             0.100000
# 4  P12             0.083333
# 5  SEC             0.071429
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/zaneshango/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
